# %%
# !pip install -r requirements.txt

import plotly.offline as py
import plotly.graph_objs as go

py.init_notebook_mode(connected=True)

# Uncomment for use in Jupyter Notebook
# %matplotlib widget
# Out:
# ...
#   Using cached CFEDemands-0.6.1-py2.py3-none-any.whl (45 kB)
# ...
#   Using cached ConsumerDemands-0.4.2.dev0-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached python_gnupg-0.5.2-py2.py3-none-any.whl (20 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 4.1 MB/s eta 0:00:0000:0100:010m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.8/450.8 kB 6.9 MB/s eta 0:00:0000:01
# ...
#   Using cached ray-2.10.0-cp39-cp39-manylinux2014_x86_64.whl (65.1 MB)
# ...
#   Using cached shortuuid-1.0.13-py3-none-any.whl (10 kB)
# ...
#   Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# ...
#   Using cached dvc_studio_client-0.20.0-py3-none-any.whl (16 kB)
# ...
#   Using cached voluptuous-0.14.2-py3-none-any.whl (31 kB)
# ...
#   Using cached shtab-1.7.1-py3-none-any.whl (14 kB)
# ...
#   Using cached tomlkit-0.12.4-py3-none-any.whl (37 kB)
# ...
#   Using cached dvc_objects-5.1.0-py3-none-any.whl (33 kB)
# ...
#   Using cached dvc_render-1.0.1-py3-none-any.whl (22 kB)
# ...
#   Using cached gto-1.7.1-py3-none-any.whl (46 kB)
# ...

# %%
import numpy as np
import pandas as pd

# %%
HH_char = pd.read_csv('HHChar_RuralMet.csv')

# %%
HH_char
# Out:
#          i     t              m  Males 00-03  Females 00-03  Males 04-08  \
# 0        1  2000  Metropolitana            0              1            0
# 1        2  2000  Metropolitana            0              0            0
# 2        3  2000  Metropolitana            0              0            0
# 3        4  2000  Metropolitana            0              0            0
# 4        5  2000  Metropolitana            0              0            1
# ...    ...   ...            ...          ...            ...          ...
# 7271  7272  2000     Suroriente            0              0            0
# 7272  7273  2000     Suroriente            1              0            1
# 7273  7274  2000     Suroriente            0              1            1
# 7274  7275  2000     Suroriente            1              0            0
# 7275  7276  2000     Suroriente            1              1            2
#
#       Females 04-08  Males 09-13  Females 09-13  Males 14-18  Females 14-18  \
# ...

# %%
HH_char['Total'] = HH_char[['Males 00-03', 'Females 00-03', 'Males 04-08', 
                            'Females 04-08', 'Males 09-13', 'Females 09-13', 
                            'Males 14-18', 'Females 14-18', 'Males 19-30', 
                           'Females 19-30', 'Males 31-50', 'Females 31-50', 
                            'Males 51-99', 'Females 51-99']].sum(axis=1)

# %%
HH_char
# Out:
#          i     t              m  Males 00-03  Females 00-03  Males 04-08  \
# 0        1  2000  Metropolitana            0              1            0
# 1        2  2000  Metropolitana            0              0            0
# 2        3  2000  Metropolitana            0              0            0
# 3        4  2000  Metropolitana            0              0            0
# 4        5  2000  Metropolitana            0              0            1
# ...    ...   ...            ...          ...            ...          ...
# 7271  7272  2000     Suroriente            0              0            0
# 7272  7273  2000     Suroriente            1              0            1
# 7273  7274  2000     Suroriente            0              1            1
# 7274  7275  2000     Suroriente            1              0            0
# 7275  7276  2000     Suroriente            1              1            2
#
#       Females 04-08  Males 09-13  Females 09-13  Males 14-18  Females 14-18  \
# ...
